# %%
import pandas as pd
import numpy as np
import yfinance as yf
import seaborn as sns
from yahoofinancials import YahooFinancials
from matplotlib import pyplot as plt

# %%
symbol_list = ['BAJAJ-AUTO',
 'JSWENERGY',
 'TORNTPOWER',
 'SUNPHARMA',
 'PERSISTENT',
 'COALINDIA',
 'GRASIM',
 'SUPREMEIND',
 'PETRONET',
 'INDUSTOWER']

# %%
start_date = "2021-04-01"
end_date = "2024-05-01"

# %%
data =[]
asset = []

# %%
for i in symbol_list:
    stock = pd.read_csv(f'{i}.csv', usecols=['Date','Close','Adj Close','Volume'])
    stock.set_index('Date', inplace=True)
    # Rename columns to include the stock symbol
    stock.columns = pd.MultiIndex.from_product([[i], stock.columns])
    #stock['Symbol'] = i
    data.append(stock)

# %%
type(data)
# Out:
# list

# %%
combined_df = pd.concat(data,axis=1)
# Reset index to ensure the 'Date' column is not part of the index
#combined_df.reset_index(inplace=True)

# %%
combined_df
# Out:
#              BAJAJ-AUTO                        JSWENERGY              \
#                   Close    Adj Close  Volume       Close   Adj Close
# Date
# 2021-04-01  3743.050049  3356.182861  861229   90.699997   88.316902
# 2021-04-05  3598.500000  3226.572754  723573   86.550003   84.275948
# 2021-04-06  3615.500000  3241.815674  501882   85.650002   83.399597
# 2021-04-07  3680.199951  3299.828613  346982   89.400002   87.051071
# 2021-04-08  3649.800049  3272.570801  414020   88.650002   86.320778
# ...                 ...          ...     ...         ...         ...
# 2024-04-24  8697.099609  8626.985352  319824  600.400024  598.428223
# 2024-04-25  8734.900391  8664.481445  524667  604.700012  602.714111
# 2024-04-26  8974.299805  8901.951172  521344  600.900024  598.926636
# 2024-04-29  8760.099609  8689.477539  299443  603.299988  601.318665
# 2024-04-30  8903.650391  8831.871094  360403  629.549988  627.482483
#
#                        TORNTPOWER                          SUNPHARMA  ...  \
#               Volume        Close    Adj Close   Volume        Close  ...
# Date                                                                  ...
# 2021-04-01  12835744   427.549988   397.117432   690448   610.750000  ...
# 2021-04-05   5031925   416.100006   386.482422   742898   608.799988  ...
# 2021-04-06   4786275   418.100006   388.340088   627560   620.450012  ...
# 2021-04-07   7078339   421.700012   391.683838   971550   621.049988  ...
# 2021-04-08   5101227   422.500000   392.426910  1330315   614.250000  ...
# ...              ...          ...          ...      ...          ...  ...
# 2024-04-24   3340579  1515.099976  1511.307007   371208  1485.750000  ...
# 2024-04-25   1539624  1509.800049  1506.020386   306326  1520.150024  ...
# 2024-04-26   1929533  1489.800049  1486.070435   227797  1506.550049  ...
# 2024-04-29    917096  1534.900024  1531.057495   694049  1521.599976  ...
# 2024-04-30   5137464  1501.099976  1497.342041  1052082  1502.099976  ...
#
#              GRASIM   SUPREMEIND                          PETRONET  \
#              Volume        Close    Adj Close   Volume       Close
# Date
# 2021-04-01  1275251  2020.800049  1935.501221    43191  227.750000
# 2021-04-05  1402086  2009.050049  1924.247314    22228  227.399994
# 2021-04-06   739833  1980.199951  1896.614868    26345  228.149994
# 2021-04-07   609297  1974.599976  1891.251221   107713  230.899994
# 2021-04-08  1573056  1981.650024  1898.003906    67005  230.300003
# ...             ...          ...          ...      ...         ...
# 2024-04-24  1021874  4250.450195  4235.244141   107095  298.950012
# 2024-04-25  1621547  4303.500000  4288.104492    96264  302.600006
# 2024-04-26   405679  4338.450195  4322.929688   584275  308.649994
# 2024-04-29   616995  4955.149902  4937.422852  2767650  305.000000
# 2024-04-30  1041175  5062.100098  5043.990723   900529  310.549988
#
#                                   INDUSTOWER
#              Adj Close    Volume       Close   Adj Close    Volume
# Date
# 2021-04-01  196.264496   1617459  255.449997  241.508286   3907171
# 2021-04-05  195.962891   3222576  251.800003  238.057495   1243612
# 2021-04-06  196.609207   2454664  251.000000  237.301163   1620237
# 2021-04-07  198.979034   2420861  252.050003  238.293854   2046358
# 2021-04-08  198.461975   1822310  263.750000  249.355301   7685517
# ...                ...       ...         ...         ...       ...
# 2024-04-24  298.950012   9963477  348.350006  348.350006  20859429
# 2024-04-25  302.600006   6376314  351.649994  351.649994  15367285
# 2024-04-26  308.649994   8714390  353.299988  353.299988  11226725
# 2024-04-29  305.000000   2883023  352.000000  352.000000  14121040
# 2024-04-30  310.549988  13142286  354.799988  354.799988  15377757
#
# [760 rows x 30 columns]

# %%
combined_df.columns.names=['Company','Info']
combined_df
# Out:
# Company      BAJAJ-AUTO                        JSWENERGY              \
# Info              Close    Adj Close  Volume       Close   Adj Close
# Date
# 2021-04-01  3743.050049  3356.182861  861229   90.699997   88.316902
# 2021-04-05  3598.500000  3226.572754  723573   86.550003   84.275948
# 2021-04-06  3615.500000  3241.815674  501882   85.650002   83.399597
# 2021-04-07  3680.199951  3299.828613  346982   89.400002   87.051071
# 2021-04-08  3649.800049  3272.570801  414020   88.650002   86.320778
# ...                 ...          ...     ...         ...         ...
# 2024-04-24  8697.099609  8626.985352  319824  600.400024  598.428223
# 2024-04-25  8734.900391  8664.481445  524667  604.700012  602.714111
# 2024-04-26  8974.299805  8901.951172  521344  600.900024  598.926636
# 2024-04-29  8760.099609  8689.477539  299443  603.299988  601.318665
# 2024-04-30  8903.650391  8831.871094  360403  629.549988  627.482483
#
# Company                TORNTPOWER                          SUNPHARMA  ...  \
# Info          Volume        Close    Adj Close   Volume        Close  ...
# Date                                                                  ...
# 2021-04-01  12835744   427.549988   397.117432   690448   610.750000  ...
# 2021-04-05   5031925   416.100006   386.482422   742898   608.799988  ...
# 2021-04-06   4786275   418.100006   388.340088   627560   620.450012  ...
# 2021-04-07   7078339   421.700012   391.683838   971550   621.049988  ...
# 2021-04-08   5101227   422.500000   392.426910  1330315   614.250000  ...
# ...              ...          ...          ...      ...          ...  ...
# 2024-04-24   3340579  1515.099976  1511.307007   371208  1485.750000  ...
# 2024-04-25   1539624  1509.800049  1506.020386   306326  1520.150024  ...
# 2024-04-26   1929533  1489.800049  1486.070435   227797  1506.550049  ...
# 2024-04-29    917096  1534.900024  1531.057495   694049  1521.599976  ...
# 2024-04-30   5137464  1501.099976  1497.342041  1052082  1502.099976  ...
#
# Company      GRASIM   SUPREMEIND                          PETRONET  \
# Info         Volume        Close    Adj Close   Volume       Close
# Date
# 2021-04-01  1275251  2020.800049  1935.501221    43191  227.750000
# 2021-04-05  1402086  2009.050049  1924.247314    22228  227.399994
# 2021-04-06   739833  1980.199951  1896.614868    26345  228.149994
# 2021-04-07   609297  1974.599976  1891.251221   107713  230.899994
# 2021-04-08  1573056  1981.650024  1898.003906    67005  230.300003
# ...             ...          ...          ...      ...         ...
# 2024-04-24  1021874  4250.450195  4235.244141   107095  298.950012
# 2024-04-25  1621547  4303.500000  4288.104492    96264  302.600006
# 2024-04-26   405679  4338.450195  4322.929688   584275  308.649994
# 2024-04-29   616995  4955.149902  4937.422852  2767650  305.000000
# 2024-04-30  1041175  5062.100098  5043.990723   900529  310.549988
#
# Company                           INDUSTOWER
# Info         Adj Close    Volume       Close   Adj Close    Volume
# Date
# 2021-04-01  196.264496   1617459  255.449997  241.508286   3907171
# 2021-04-05  195.962891   3222576  251.800003  238.057495   1243612
# 2021-04-06  196.609207   2454664  251.000000  237.301163   1620237
# 2021-04-07  198.979034   2420861  252.050003  238.293854   2046358
# 2021-04-08  198.461975   1822310  263.750000  249.355301   7685517
# ...                ...       ...         ...         ...       ...
# 2024-04-24  298.950012   9963477  348.350006  348.350006  20859429
# 2024-04-25  302.600006   6376314  351.649994  351.649994  15367285
# 2024-04-26  308.649994   8714390  353.299988  353.299988  11226725
# 2024-04-29  305.000000   2883023  352.000000  352.000000  14121040
# 2024-04-30  310.549988  13142286  354.799988  354.799988  15377757
#
# [760 rows x 30 columns]

# %%
returns = pd.DataFrame()
for stock in symbol_list:
    returns[stock+' Returns'] = combined_df[stock]['Adj Close'].pct_change()

# %%
returns.head()
#calculation of daily returns. 
#The daily percent changes is calculated using the 
#.pct_change(method) in a separate dataframe “returns”.
# Out:
#             BAJAJ-AUTO Returns  JSWENERGY Returns  TORNTPOWER Returns  \
# Date
# 2021-04-01                 NaN                NaN                 NaN
# 2021-04-05           -0.038618          -0.045755           -0.026781
# 2021-04-06            0.004724          -0.010399            0.004807
# 2021-04-07            0.017895           0.043783            0.008610
# 2021-04-08           -0.008260          -0.008389            0.001897
#
#             SUNPHARMA Returns  PERSISTENT Returns  COALINDIA Returns  \
# Date
# 2021-04-01                NaN                 NaN                NaN
# 2021-04-05          -0.003193            0.002841          -0.017783
# 2021-04-06           0.019136           -0.010721           0.003852
# 2021-04-07           0.000967            0.012566           0.007291
# 2021-04-08          -0.010949            0.025813           0.003048
#
#             GRASIM Returns  SUPREMEIND Returns  PETRONET Returns  \
# Date
# 2021-04-01             NaN                 NaN               NaN
# 2021-04-05       -0.005500           -0.005814         -0.001537
# 2021-04-06       -0.009644           -0.014360          0.003298
# 2021-04-07        0.003386           -0.002828          0.012053
# 2021-04-08        0.007235            0.003570         -0.002599
#
#             INDUSTOWER Returns
# Date
# 2021-04-01                 NaN
# 2021-04-05           -0.014288
# 2021-04-06           -0.003177
# 2021-04-07            0.004183
# 2021-04-08            0.046419

# %%
(returns.mean())*250
# Out:
# BAJAJ-AUTO Returns    0.344654
# JSWENERGY Returns     0.757439
# TORNTPOWER Returns    0.495929
# SUNPHARMA Returns     0.328822
# PERSISTENT Returns    0.473391
# COALINDIA Returns     0.547836
# GRASIM Returns        0.200369
# SUPREMEIND Returns    0.368591
# PETRONET Returns      0.181517
# INDUSTOWER Returns    0.201149
# dtype: float64

# %%
returns.cov()*250
# Out:
#                     BAJAJ-AUTO Returns  JSWENERGY Returns  TORNTPOWER Returns  \
# BAJAJ-AUTO Returns            0.051817           0.019123            0.013459
# JSWENERGY Returns             0.019123           0.225000            0.039632
# TORNTPOWER Returns            0.013459           0.039632            0.118365
# SUNPHARMA Returns             0.009564           0.014424            0.011748
# PERSISTENT Returns            0.008712           0.032761            0.016917
# COALINDIA Returns             0.010415           0.041209            0.035219
# GRASIM Returns                0.013028           0.027998            0.021522
# SUPREMEIND Returns            0.007442           0.020630            0.008635
# PETRONET Returns              0.012747           0.025658            0.020451
# INDUSTOWER Returns            0.013375           0.032209            0.031772
#
#                     SUNPHARMA Returns  PERSISTENT Returns  COALINDIA Returns  \
# BAJAJ-AUTO Returns           0.009564            0.008712           0.010415
# JSWENERGY Returns            0.014424            0.032761           0.041209
# TORNTPOWER Returns           0.011748            0.016917           0.035219
# SUNPHARMA Returns            0.044827            0.017375           0.014947
# PERSISTENT Returns           0.017375            0.116169           0.022782
# COALINDIA Returns            0.014947            0.022782           0.092857
# GRASIM Returns               0.012864            0.019811           0.021446
# SUPREMEIND Returns           0.010362            0.018355           0.015113
# PETRONET Returns             0.009022            0.011832           0.028164
# INDUSTOWER Returns           0.010318            0.017611           0.024914
#
#                     GRASIM Returns  SUPREMEIND Returns  PETRONET Returns  \
# BAJAJ-AUTO Returns        0.013028            0.007442          0.012747
# JSWENERGY Returns         0.027998            0.020630          0.025658
# TORNTPOWER Returns        0.021522            0.008635          0.020451
# SUNPHARMA Returns         0.012864            0.010362          0.009022
# PERSISTENT Returns        0.019811            0.018355          0.011832
# COALINDIA Returns         0.021446            0.015113          0.028164
# GRASIM Returns            0.057427            0.016889          0.012416
# SUPREMEIND Returns        0.016889            0.107033          0.001041
# PETRONET Returns          0.012416            0.001041          0.060661
# INDUSTOWER Returns        0.031071            0.011960          0.023677
#
#                     INDUSTOWER Returns
# BAJAJ-AUTO Returns            0.013375
# JSWENERGY Returns             0.032209
# TORNTPOWER Returns            0.031772
# SUNPHARMA Returns             0.010318
# PERSISTENT Returns            0.017611
# COALINDIA Returns             0.024914
# GRASIM Returns                0.031071
# SUPREMEIND Returns            0.011960
# PETRONET Returns              0.023677
# INDUSTOWER Returns            0.148501

# %% [markdown]
# #single run
# np.random.seed(101)
# weights = np.array(np.random.random(21))
# print('Random weights')
# print(weights)
# print('Rebalanced weights')
# weights = weights/np.sum(weights)
# print('Portfolio return')
# port_ret = np.sum(returns.mean()*250*weights)
# print(port_ret)
# print('Expected volatility')
# port_vol = np.sqrt(np.dot(weights.T, np.dot(returns.cov()*250,weights)))
# print(port_vol)
# print('Sharpe Ratio')
# SR = (port_ret - 0.075)/port_vol
# print(SR)

# %%
sim = 5000
all_weights = np.zeros((sim, len(symbol_list)))
ret_arr = np.zeros(sim)
vol_arr = np.zeros(sim)
sharpe_arr = np.zeros(sim)

for i in range(sim):
    weights = np.array(np.random.random(10))
    weights = weights/np.sum(weights)
    all_weights[i,:] = weights
    ret_arr[i] = np.sum(returns.mean()*250*weights)
    vol_arr[i] = np.sqrt(np.dot(weights.T,np.dot(returns.cov()*250,weights)))
    sharpe_arr[i] = (ret_arr[i] - 0.075)/vol_arr[i]

# %%
sharpe_arr.max()
# Out:
# 2.2104508009475246

# %%
sharpe_arr.argmax()
# Out:
# 4202

# %%
weights = all_weights[4202,:]

# %%
df = pd.DataFrame({
    'Symbol': symbol_list,
    'Weight': weights
})

# Sort the DataFrame by the weight values
df_sorted = df.sort_values(by='Weight', ascending=False)

# Display the sorted DataFrame
print(df_sorted)
# Out:
#        Symbol    Weight
# 5   COALINDIA  0.205746
# 1   JSWENERGY  0.174527
# 4  PERSISTENT  0.154029
# 3   SUNPHARMA  0.141842
# 0  BAJAJ-AUTO  0.120082
# 2  TORNTPOWER  0.103826
# 7  SUPREMEIND  0.056351
# 9  INDUSTOWER  0.022529
# 8    PETRONET  0.014789
# 6      GRASIM  0.006278

# %%
stocks = df_sorted['Symbol'].tolist()
stocks
# Out:
# ['COALINDIA',
#  'JSWENERGY',
#  'PERSISTENT',
#  'SUNPHARMA',
#  'BAJAJ-AUTO',
#  'TORNTPOWER',
#  'SUPREMEIND',
#  'INDUSTOWER',
#  'PETRONET',
#  'GRASIM']

# %%
prices = []
start_date = '2020-04-01'
for symbol in stocks:
        # Fetch historical data from Yahoo Finance
        data = yf.download(symbol+".NS", start="2020-04-01", end='2020-04-02')
        price_april2020 = data.loc[start_date]['Adj Close']
        prices.append(price_april2020)
df_prices = pd.DataFrame({'Symbol': stocks, 'Price_April2020': prices})

# Display the prices
print(df_prices)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#        Symbol  Price_April2020
# 0   COALINDIA        95.256004
# 1   JSWENERGY        41.094852
# 2  PERSISTENT       262.679840
# 3   SUNPHARMA       328.683655
# 4  BAJAJ-AUTO      1839.106323
# 5  TORNTPOWER       256.646759
# 6  SUPREMEIND       801.269592
# 7  INDUSTOWER       131.432846
# 8    PETRONET       161.202744
# 9      GRASIM       466.172974

# %%
prices=[]

# %%
start_date = '2024-06-03'
for symbol in stocks:
        # Fetch historical data from Yahoo Finance
        data = yf.download(symbol+".NS", start="2024-06-03", end='2024-06-04')
        price_2024 = data.loc[start_date]['Adj Close']
        prices.append(price_2024)
df_prices2 = pd.DataFrame({'Symbol': stocks, 'Price_2024': prices})

# Display the prices
print(df_prices2)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#        Symbol   Price_2024
# 0   COALINDIA   512.349976
# 1   JSWENERGY   658.700012
# 2  PERSISTENT  3418.380371
# 3   SUNPHARMA  1448.456909
# 4  BAJAJ-AUTO  9260.190430
# 5  TORNTPOWER  1511.456665
# 6  SUPREMEIND  5547.382812
# 7  INDUSTOWER   364.000000
# 8    PETRONET   313.968658
# 9      GRASIM  2368.800049

# %%
combined_df = pd.merge(df_prices, df_prices2, on='Symbol')

# %%
combined_df = pd.merge(df_sorted, combined_df, on='Symbol')

# %%
combined_df
# Out:
#        Symbol    Weight  Price_April2020   Price_2024
# 0   COALINDIA  0.205746        95.256004   512.349976
# 1   JSWENERGY  0.174527        41.094852   658.700012
# 2  PERSISTENT  0.154029       262.679840  3418.380371
# 3   SUNPHARMA  0.141842       328.683655  1448.456909
# 4  BAJAJ-AUTO  0.120082      1839.106323  9260.190430
# 5  TORNTPOWER  0.103826       256.646759  1511.456665
# 6  SUPREMEIND  0.056351       801.269592  5547.382812
# 7  INDUSTOWER  0.022529       131.432846   364.000000
# 8    PETRONET  0.014789       161.202744   313.968658
# 9      GRASIM  0.006278       466.172974  2368.800049

# %%
portfolio_value = 10000000
combined_df['Investment'] = combined_df['Weight'] * portfolio_value
combined_df['Shares'] = (combined_df['Investment'] / combined_df['Price_April2020']).astype(int)

# Calculate the value of each stock on 1st June 2024
combined_df['Value_2024'] = combined_df['Shares'] * combined_df['Price_2024']

# Calculate total investment used and remaining cash
total_investment_used = (combined_df['Shares'] * combined_df['Price_April2020']).sum()
remaining_cash = portfolio_value - total_investment_used

# Calculate total portfolio value in June 2024 and profit/loss
total_value_2024 = combined_df['Value_2024'].sum()
profit_loss = total_value_2024 - total_investment_used

# %%
combined_df
# Out:
#        Symbol    Weight  Price_April2020   Price_2024    Investment  Shares  \
# 0   COALINDIA  0.205746        95.256004   512.349976  2.057459e+06   21599
# 1   JSWENERGY  0.174527        41.094852   658.700012  1.745267e+06   42469
# 2  PERSISTENT  0.154029       262.679840  3418.380371  1.540291e+06    5863
# 3   SUNPHARMA  0.141842       328.683655  1448.456909  1.418422e+06    4315
# 4  BAJAJ-AUTO  0.120082      1839.106323  9260.190430  1.200818e+06     652
# 5  TORNTPOWER  0.103826       256.646759  1511.456665  1.038264e+06    4045
# 6  SUPREMEIND  0.056351       801.269592  5547.382812  5.635141e+05     703
# 7  INDUSTOWER  0.022529       131.432846   364.000000  2.252941e+05    1714
# 8    PETRONET  0.014789       161.202744   313.968658  1.478925e+05     917
# 9      GRASIM  0.006278       466.172974  2368.800049  6.277808e+04     134
#
#      Value_2024
# 0  1.106625e+07
# 1  2.797433e+07
# 2  2.004196e+07
# 3  6.250092e+06
# 4  6.037644e+06
# 5  6.113842e+06
# 6  3.899810e+06
# 7  6.238960e+05
# 8  2.879093e+05
# 9  3.174192e+05

# %%
# Display the final DataFrame and summary
print(combined_df)
print("\nSummary:")
print(f"Total Investment Used: Rs.{total_investment_used:.2f}")
print(f"Remaining Cash: Rs.{remaining_cash:.2f}")
print(f"Total Portfolio Value in June 2024: Rs.{total_value_2024:.2f}")
print(f"Total Profit: Rs.{profit_loss:.2f}")
print(f"Total Profit %: {profit_loss/total_investment_used*100:.2f}")
# Out:
#        Symbol    Weight  Price_April2020   Price_2024    Investment  Shares  \
# 0   COALINDIA  0.205746        95.256004   512.349976  2.057459e+06   21599
# 1   JSWENERGY  0.174527        41.094852   658.700012  1.745267e+06   42469
# 2  PERSISTENT  0.154029       262.679840  3418.380371  1.540291e+06    5863
# 3   SUNPHARMA  0.141842       328.683655  1448.456909  1.418422e+06    4315
# 4  BAJAJ-AUTO  0.120082      1839.106323  9260.190430  1.200818e+06     652
# 5  TORNTPOWER  0.103826       256.646759  1511.456665  1.038264e+06    4045
# 6  SUPREMEIND  0.056351       801.269592  5547.382812  5.635141e+05     703
# 7  INDUSTOWER  0.022529       131.432846   364.000000  2.252941e+05    1714
# 8    PETRONET  0.014789       161.202744   313.968658  1.478925e+05     917
# 9      GRASIM  0.006278       466.172974  2368.800049  6.277808e+04     134
#
#      Value_2024
# 0  1.106625e+07
# 1  2.797433e+07
# 2  2.004196e+07
# 3  6.250092e+06
# 4  6.037644e+06
# 5  6.113842e+06
# 6  3.899810e+06
# 7  6.238960e+05
# 8  2.879093e+05
# 9  3.174192e+05
#
# Summary:
# Total Investment Used: Rs.9997145.58
# Remaining Cash: Rs.2854.42
# Total Portfolio Value in June 2024: Rs.82613154.57
# Total Profit: Rs.72616009.00
# Total Profit %: 726.37
