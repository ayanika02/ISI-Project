# %%
import numpy as np
import pandas as pd

# %%
# !pip install nselib
# Out:
# ...
#      ---------------------------------------- 46.2/46.2 MB 1.8 MB/s eta 0:00:00
# ...

# %%
import nselib
from nselib import capital_market

# %%
nselib.trading_holiday_calendar()
# Out:
#                                    Product  tradingDate    weekDay  \
# 0                          Corporate Bonds  22-Jan-2024     Monday
# 1                          Corporate Bonds  26-Jan-2024     Friday
# 2                          Corporate Bonds  19-Feb-2024     Monday
# 3                          Corporate Bonds  08-Mar-2024     Friday
# 4                          Corporate Bonds  25-Mar-2024     Monday
# ..                                     ...          ...        ...
# 16  Securities Lending & Borrowing Schemes  12-Oct-2024   Saturday
# 17  Securities Lending & Borrowing Schemes  01-Nov-2024     Friday
# 18  Securities Lending & Borrowing Schemes  02-Nov-2024   Saturday
# 19  Securities Lending & Borrowing Schemes  15-Nov-2024     Friday
# 20  Securities Lending & Borrowing Schemes  25-Dec-2024  Wednesday
#
#                            description Sr_no
# 0                      Special Holiday     1
# 1                         Republic Day     2
# ...

# %%
capital_market.bhav_copy_equities("21-06-2023")
# Out:
#           SYMBOL SERIES     OPEN     HIGH      LOW    CLOSE     LAST  \
# 0     182D140923     TB    98.20    98.20    98.20    98.20    98.20
# 1     182D191023     TB    97.46    97.46    97.46    97.46    97.46
# 2      20MICRONS     EQ    99.00   103.60    99.00   101.25   100.90
# 3     21STCENMGM     EQ    21.65    21.65    21.65    21.65    21.65
# 4         360ONE     EQ   441.70   449.40   438.65   439.95   442.00
# ...          ...    ...      ...      ...      ...      ...      ...
# 2429        ZOTA     EQ   386.40   390.75   381.00   388.50   388.50
# 2430       ZUARI     EQ   149.90   153.95   147.15   147.70   148.20
# 2431    ZUARIIND     EQ   146.60   152.05   144.00   145.10   145.20
# 2432   ZYDUSLIFE     EQ   557.40   564.80   552.30   560.10   561.30
# 2433   ZYDUSWELL     EQ  1512.00  1525.00  1488.00  1508.85  1515.00
#
#       PREVCLOSE  TOTTRDQTY     TOTTRDVAL    TIMESTAMP  TOTALTRADES
# 0         98.07        500  4.910000e+04  21-JUN-2023            1
# ...

# %%
df = pd.DataFrame()

# %%
end_date = "01-01-2021"
start_date = "31-12-23"
date_strings = []
current_date = start_date
while current_date <= end_date:
    date_str = current_date.strftime("%d-%m-%Y")
    date_strings.append(date_str)
    current_date += datetime.timedelta(days=1)
    df.append(capital_market.bhav_copy_equities(current_date))
    
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
help(capital_market.bhav_copy_equities)
# Out:
# Help on function bhav_copy_equities in module nselib.capital_market.capital_market_data:
#
# bhav_copy_equities(trade_date: str)
#     get nse bhav copy as per the traded date provided
#     :param trade_date:
#     :return: pandas dataframe

# %%
capital_market.bhav_copy_with_delivery("21-06-2024")
# Out:
#           SYMBOL SERIES  OPEN_PRICE  HIGH_PRICE  LOW_PRICE  CLOSE_PRICE  \
# 0     1018GS2026     GS      115.90      119.51     113.82       117.60
# 1      20MICRONS     EQ      187.00      218.65     183.50       213.77
# 2     21STCENMGM     BE       60.32       60.32      60.32        60.32
# 3         360ONE     EQ      849.60      861.00     831.10       837.60
# 4      3IINFOLTD     EQ       37.74       38.50      36.90        37.12
# ...          ...    ...         ...         ...        ...          ...
# 2570       ZTECH     SM      196.70      196.70     187.00       196.70
# 2571       ZUARI     EQ      228.50      232.60     208.73       213.93
# 2572    ZUARIIND     EQ      364.70      369.95     340.50       346.30
# 2573   ZYDUSLIFE     EQ     1095.00     1102.90    1079.00      1085.05
# 2574   ZYDUSWELL     EQ     1899.00     1899.00    1850.00      1856.55
#
#       PREV_CLOSE  TTL_TRD_QNTY  TURNOVER_LACS  NO_OF_TRADES DELIV_QTY  \
# ...

# %%
help(capital_market.bhav_copy_with_delivery)
# Out:
# Help on function bhav_copy_with_delivery in module nselib.capital_market.capital_market_data:
#
# bhav_copy_with_delivery(trade_date: str)
#     get the NSE bhav copy with delivery data as per the traded date
#     :param trade_date: eg:'01-06-2023'
#     :return: pandas data frame

# %%
capital_market.block_deals_data(period = "1Y")
# Out:
#              Date     Symbol               SecurityName  \
# 0     22-JUN-2023  CRAFTSMAN   Craftsman Automation Ltd
# 1     22-JUN-2023  CRAFTSMAN   Craftsman Automation Ltd
# 2     22-JUN-2023  CRAFTSMAN   Craftsman Automation Ltd
# 3     22-JUN-2023  CRAFTSMAN   Craftsman Automation Ltd
# 4     22-JUN-2023  CRAFTSMAN   Craftsman Automation Ltd
# ...           ...        ...                        ...
# 1522  20-JUN-2024   RATEGAIN  Rategain Travel Techn ltd
# 1523  20-JUN-2024   RATEGAIN  Rategain Travel Techn ltd
# 1524  20-JUN-2024   RATEGAIN  Rategain Travel Techn ltd
# 1525  21-JUN-2024        PEL   Piramal Enterprises Ltd.
# 1526  21-JUN-2024        PEL   Piramal Enterprises Ltd.
#
#                                              ClientName Buy/Sell  \
# 0                                      AXIS MUTUAL FUND      BUY
# 1     GOLDMAN SACHS FUNDS-GOLDMAN SACHS ASIA EQUITY ...      BUY
# 2                MANULIFE GLOBAL FUND INDIA EQUITY FUND      BUY
# ...

# %%
capital_market.bulk_deal_data(period = "1Y")
# Out:
#               Date    Symbol               SecurityName  \
# 0      22-JUN-2023  ACCURACY  Accuracy Shipping Limited
# 1      22-JUN-2023      ADSL  Allied Digital Services L
# 2      22-JUN-2023      ADSL  Allied Digital Services L
# 3      22-JUN-2023       AHL     Abans Holdings Limited
# 4      22-JUN-2023       AHL     Abans Holdings Limited
# ...            ...       ...                        ...
# 25371  21-JUN-2024     ZTECH     Z-Tech (India) Limited
# 25372  21-JUN-2024     ZTECH     Z-Tech (India) Limited
# 25373  21-JUN-2024     ZTECH     Z-Tech (India) Limited
# 25374  21-JUN-2024     ZTECH     Z-Tech (India) Limited
# 25375  21-JUN-2024     ZTECH     Z-Tech (India) Limited
#
#                                               ClientName Buy/Sell  \
# 0                        ANTARA INDIA EVERGREEN FUND LTD     SELL
# 1                          GRAVITON RESEARCH CAPITAL LLP      BUY
# 2                          GRAVITON RESEARCH CAPITAL LLP     SELL
# ...

# %%
capital_market.equity_list('NIFTY 200')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 capital_market.equity_list('NIFTY 200')
#
# TypeError: equity_list() takes 0 positional arguments but 1 was given

# %%
capital_market.fno_equity_list() #futures and options

# %%
capital_market.index_data('SBIN', period='1M')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\nselib\capital_market\capital_market_data.py:235, in get_index_data(index, from_date, to_date)
#     234 data_json = nse_urlfetch(url).json()
# --> 235 data_close_df = pd.DataFrame(data_json['data']['indexCloseOnlineRecords']).drop(columns=['_id', "EOD_TIMESTAMP"])
#     236 data_turnover_df = pd.DataFrame(data_json['data']['indexTurnoverRecords']).drop(columns=['_id',
#     237                                                                                          'HIT_INDEX_NAME_UPPER'])
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5121 """
#    5122 Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256         weight  1.0     0.8
#    5257 """
# ...

# %%
capital_market.nifty100_equity_list()

# %%
print(2+2)
