# %%
import pandas as pd
import numpy as np
import yfinance as yf
import seaborn as sns
from yahoofinancials import YahooFinancials
from matplotlib import pyplot as plt

# %%
symbol_list = ['ASHOKLEY',
 'ASIANPAINT',
 'BAJAJ-AUTO',
 'BRITANNIA',
 'COALINDIA',
 'ADANIPORTS',
 'APOLLOTYRE',
 'DIVISLAB',
 'LALPATHLAB',
 'GRASIM',
 'INDUSTOWER',
 'JSWENERGY',
 'OBEROIRLTY',
 'PERSISTENT',
 'PETRONET',
 'PIDILITIND',
 'PRESTIGE',
 'SUNPHARMA',
 'SUPREMEIND',
 'TORNTPOWER',
 'ULTRACEMCO']

# %%
start_date = "2021-04-01"
end_date = "2024-05-01"

# %%
data =[]
asset = []

# %%
for i in symbol_list:
    stock = pd.read_csv(f'{i}.csv', usecols=['Date','Close','Adj Close','Volume'])
    stock.set_index('Date', inplace=True)
    # Rename columns to include the stock symbol
    stock.columns = pd.MultiIndex.from_product([[i], stock.columns])
    #stock['Symbol'] = i
    data.append(stock)

# %%
type(data)
# Out:
# list

# %%
combined_df = pd.concat(data,axis=1)
# Reset index to ensure the 'Date' column is not part of the index
#combined_df.reset_index(inplace=True)

# %%
combined_df
# Out:
#               ASHOKLEY                         ASIANPAINT               \
#                  Close   Adj Close    Volume        Close    Adj Close
# Date
# 2021-04-01  118.150002  109.928116  21938734  2551.750000  2473.075439
# 2021-04-05  113.349998  105.462135  22361908  2510.649902  2433.242188
# 2021-04-06  112.500000  104.671288  15611581  2611.600098  2531.080078
# 2021-04-07  116.750000  108.625549  21921323  2628.600098  2547.555908
# 2021-04-08  122.750000  114.208015  54015926  2650.649902  2568.925781
# ...                ...         ...       ...          ...          ...
# 2024-04-24  177.600006  177.600006  13300471  2867.750000  2840.268799
# 2024-04-25  177.699997  177.699997  11988994  2861.449951  2834.029297
# 2024-04-26  185.000000  185.000000  48050897  2844.149902  2816.895020
# 2024-04-29  185.350006  185.350006  15675179  2868.199951  2840.714600
# 2024-04-30  192.649994  192.649994  55035190  2875.899902  2848.340576
#
#                       BAJAJ-AUTO                         BRITANNIA  ...  \
#              Volume        Close    Adj Close  Volume        Close  ...
# Date                                                                ...
# 2021-04-01  1219588  3743.050049  3356.182861  861229  3618.500000  ...
# 2021-04-05  1268939  3598.500000  3226.572754  723573  3700.350098  ...
# 2021-04-06  3372846  3615.500000  3241.815674  501882  3730.600098  ...
# 2021-04-07  1937977  3680.199951  3299.828613  346982  3808.550049  ...
# 2021-04-08   897483  3649.800049  3272.570801  414020  3816.750000  ...
# ...             ...          ...          ...     ...          ...  ...
# 2024-04-24   718441  8697.099609  8626.985352  319824  4828.950195  ...
# 2024-04-25  1594152  8734.900391  8664.481445  524667  4844.149902  ...
# 2024-04-26   625507  8974.299805  8901.951172  521344  4800.450195  ...
# 2024-04-29   566219  8760.099609  8689.477539  299443  4799.850098  ...
# 2024-04-30  1290649  8903.650391  8831.871094  360403  4775.950195  ...
#
#            SUNPHARMA   SUPREMEIND                         TORNTPOWER  \
#               Volume        Close    Adj Close   Volume        Close
# Date
# 2021-04-01   6033653  2020.800049  1935.501221    43191   427.549988
# 2021-04-05   5353987  2009.050049  1924.247314    22228   416.100006
# 2021-04-06   7444994  1980.199951  1896.614868    26345   418.100006
# 2021-04-07   4757224  1974.599976  1891.251221   107713   421.700012
# 2021-04-08   3222479  1981.650024  1898.003906    67005   422.500000
# ...              ...          ...          ...      ...          ...
# 2024-04-24   4652803  4250.450195  4235.244141   107095  1515.099976
# 2024-04-25   3846327  4303.500000  4288.104492    96264  1509.800049
# 2024-04-26   1794350  4338.450195  4322.929688   584275  1489.800049
# 2024-04-29   1091667  4955.149902  4937.422852  2767650  1534.900024
# 2024-04-30   1991646  5062.100098  5043.990723   900529  1501.099976
#
#                                    ULTRACEMCO
#               Adj Close   Volume        Close    Adj Close  Volume
# Date
# 2021-04-01   397.117432   690448  6898.850098  6795.105957  531749
# 2021-04-05   386.482422   742898  6795.799805  6693.605469  540954
# 2021-04-06   388.340088   627560  6736.649902  6635.345215  508328
# 2021-04-07   391.683838   971550  6760.049805  6658.393066  301479
# 2021-04-08   392.426910  1330315  6971.250000  6866.417480  635298
# ...                 ...      ...          ...          ...     ...
# 2024-04-24  1511.307007   371208  9658.849609  9658.849609  317929
# 2024-04-25  1506.020386   306326  9683.750000  9683.750000  398260
# 2024-04-26  1486.070435   227797  9700.900391  9700.900391  265782
# 2024-04-29  1531.057495   694049  9964.450195  9964.450195  808505
# 2024-04-30  1497.342041  1052082  9971.849609  9971.849609  777837
#
# [760 rows x 63 columns]

# %%
combined_df.columns.names=['Company','Info']
combined_df
# Out:
# Company       ASHOKLEY                         ASIANPAINT               \
# Info             Close   Adj Close    Volume        Close    Adj Close
# Date
# 2021-04-01  118.150002  109.928116  21938734  2551.750000  2473.075439
# 2021-04-05  113.349998  105.462135  22361908  2510.649902  2433.242188
# 2021-04-06  112.500000  104.671288  15611581  2611.600098  2531.080078
# 2021-04-07  116.750000  108.625549  21921323  2628.600098  2547.555908
# 2021-04-08  122.750000  114.208015  54015926  2650.649902  2568.925781
# ...                ...         ...       ...          ...          ...
# 2024-04-24  177.600006  177.600006  13300471  2867.750000  2840.268799
# 2024-04-25  177.699997  177.699997  11988994  2861.449951  2834.029297
# 2024-04-26  185.000000  185.000000  48050897  2844.149902  2816.895020
# 2024-04-29  185.350006  185.350006  15675179  2868.199951  2840.714600
# 2024-04-30  192.649994  192.649994  55035190  2875.899902  2848.340576
#
# Company               BAJAJ-AUTO                         BRITANNIA  ...  \
# Info         Volume        Close    Adj Close  Volume        Close  ...
# Date                                                                ...
# 2021-04-01  1219588  3743.050049  3356.182861  861229  3618.500000  ...
# 2021-04-05  1268939  3598.500000  3226.572754  723573  3700.350098  ...
# 2021-04-06  3372846  3615.500000  3241.815674  501882  3730.600098  ...
# 2021-04-07  1937977  3680.199951  3299.828613  346982  3808.550049  ...
# 2021-04-08   897483  3649.800049  3272.570801  414020  3816.750000  ...
# ...             ...          ...          ...     ...          ...  ...
# 2024-04-24   718441  8697.099609  8626.985352  319824  4828.950195  ...
# 2024-04-25  1594152  8734.900391  8664.481445  524667  4844.149902  ...
# 2024-04-26   625507  8974.299805  8901.951172  521344  4800.450195  ...
# 2024-04-29   566219  8760.099609  8689.477539  299443  4799.850098  ...
# 2024-04-30  1290649  8903.650391  8831.871094  360403  4775.950195  ...
#
# Company    SUNPHARMA   SUPREMEIND                         TORNTPOWER  \
# Info          Volume        Close    Adj Close   Volume        Close
# Date
# 2021-04-01   6033653  2020.800049  1935.501221    43191   427.549988
# 2021-04-05   5353987  2009.050049  1924.247314    22228   416.100006
# 2021-04-06   7444994  1980.199951  1896.614868    26345   418.100006
# 2021-04-07   4757224  1974.599976  1891.251221   107713   421.700012
# 2021-04-08   3222479  1981.650024  1898.003906    67005   422.500000
# ...              ...          ...          ...      ...          ...
# 2024-04-24   4652803  4250.450195  4235.244141   107095  1515.099976
# 2024-04-25   3846327  4303.500000  4288.104492    96264  1509.800049
# 2024-04-26   1794350  4338.450195  4322.929688   584275  1489.800049
# 2024-04-29   1091667  4955.149902  4937.422852  2767650  1534.900024
# 2024-04-30   1991646  5062.100098  5043.990723   900529  1501.099976
#
# Company                            ULTRACEMCO
# Info          Adj Close   Volume        Close    Adj Close  Volume
# Date
# 2021-04-01   397.117432   690448  6898.850098  6795.105957  531749
# 2021-04-05   386.482422   742898  6795.799805  6693.605469  540954
# 2021-04-06   388.340088   627560  6736.649902  6635.345215  508328
# 2021-04-07   391.683838   971550  6760.049805  6658.393066  301479
# 2021-04-08   392.426910  1330315  6971.250000  6866.417480  635298
# ...                 ...      ...          ...          ...     ...
# 2024-04-24  1511.307007   371208  9658.849609  9658.849609  317929
# 2024-04-25  1506.020386   306326  9683.750000  9683.750000  398260
# 2024-04-26  1486.070435   227797  9700.900391  9700.900391  265782
# 2024-04-29  1531.057495   694049  9964.450195  9964.450195  808505
# 2024-04-30  1497.342041  1052082  9971.849609  9971.849609  777837
#
# [760 rows x 63 columns]

# %%
returns = pd.DataFrame()
for stock in symbol_list:
    returns[stock+' Returns'] = combined_df[stock]['Adj Close'].pct_change()

# %%
returns.head()
#calculation of daily returns. 
#The daily percent changes is calculated using the 
#.pct_change(method) in a separate dataframe “returns”.
# Out:
#             ASHOKLEY Returns  ASIANPAINT Returns  BAJAJ-AUTO Returns  \
# Date
# 2021-04-01               NaN                 NaN                 NaN
# 2021-04-05         -0.040626           -0.016107           -0.038618
# 2021-04-06         -0.007499            0.040209            0.004724
# 2021-04-07          0.037778            0.006509            0.017895
# 2021-04-08          0.051392            0.008388           -0.008260
#
#             BRITANNIA Returns  COALINDIA Returns  ADANIPORTS Returns  \
# Date
# 2021-04-01                NaN                NaN                 NaN
# 2021-04-05           0.022620          -0.017783            0.008150
# 2021-04-06           0.008175           0.003852            0.125699
# 2021-04-07           0.020895           0.007291           -0.024894
# 2021-04-08           0.018737           0.003048            0.010126
#
#             APOLLOTYRE Returns  DIVISLAB Returns  LALPATHLAB Returns  \
# Date
# 2021-04-01                 NaN               NaN                 NaN
# 2021-04-05           -0.060580         -0.001397            0.061415
# 2021-04-06            0.004510          0.021337            0.056136
# 2021-04-07            0.013244          0.002942           -0.024061
# 2021-04-08           -0.006203          0.004379            0.048906
#
#             GRASIM Returns  ...  JSWENERGY Returns  OBEROIRLTY Returns  \
# Date                        ...
# 2021-04-01             NaN  ...                NaN                 NaN
# 2021-04-05       -0.005500  ...          -0.045755           -0.010797
# 2021-04-06       -0.009644  ...          -0.010399           -0.010304
# 2021-04-07        0.003386  ...           0.043783            0.013587
# 2021-04-08        0.007235  ...          -0.008389            0.009836
#
#             PERSISTENT Returns  PETRONET Returns  PIDILITIND Returns  \
# Date
# 2021-04-01                 NaN               NaN                 NaN
# 2021-04-05            0.002841         -0.001537           -0.012972
# 2021-04-06           -0.010721          0.003298            0.041623
# 2021-04-07            0.012566          0.012053            0.007469
# 2021-04-08            0.025813         -0.002599            0.009108
#
#             PRESTIGE Returns  SUNPHARMA Returns  SUPREMEIND Returns  \
# Date
# 2021-04-01               NaN                NaN                 NaN
# 2021-04-05         -0.030435          -0.003193           -0.005814
# 2021-04-06          0.030055           0.019136           -0.014360
# 2021-04-07          0.008429           0.000967           -0.002828
# 2021-04-08          0.001447          -0.010949            0.003570
#
#             TORNTPOWER Returns  ULTRACEMCO Returns
# Date
# 2021-04-01                 NaN                 NaN
# 2021-04-05           -0.026781           -0.014937
# 2021-04-06            0.004807           -0.008704
# 2021-04-07            0.008610            0.003473
# 2021-04-08            0.001897            0.031242
#
# [5 rows x 21 columns]

# %%
(returns.mean())*250
# Out:
# ASHOKLEY Returns      0.229241
# ASIANPAINT Returns    0.071941
# BAJAJ-AUTO Returns    0.344654
# BRITANNIA Returns     0.133817
# COALINDIA Returns     0.547836
# ADANIPORTS Returns    0.279889
# APOLLOTYRE Returns    0.315172
# DIVISLAB Returns      0.079411
# LALPATHLAB Returns    0.021579
# GRASIM Returns        0.200369
# INDUSTOWER Returns    0.201149
# JSWENERGY Returns     0.757439
# OBEROIRLTY Returns    0.377854
# PERSISTENT Returns    0.473391
# PETRONET Returns      0.181517
# PIDILITIND Returns    0.197882
# PRESTIGE Returns      0.576878
# SUNPHARMA Returns     0.328822
# SUPREMEIND Returns    0.368591
# TORNTPOWER Returns    0.495929
# ULTRACEMCO Returns    0.152444
# dtype: float64

# %%
returns.cov()*250
# Out:
#                     ASHOKLEY Returns  ASIANPAINT Returns  BAJAJ-AUTO Returns  \
# ASHOKLEY Returns            0.088759            0.016778            0.021235
# ASIANPAINT Returns          0.016778            0.050817            0.009413
# BAJAJ-AUTO Returns          0.021235            0.009413            0.051817
# BRITANNIA Returns           0.010337            0.012802            0.004946
# COALINDIA Returns           0.026117            0.000440            0.010415
# ADANIPORTS Returns          0.037338            0.021277            0.019047
# APOLLOTYRE Returns          0.040421            0.016228            0.020274
# DIVISLAB Returns            0.011226            0.014282            0.011626
# LALPATHLAB Returns          0.017466            0.015933            0.005709
# GRASIM Returns              0.028729            0.016840            0.013028
# INDUSTOWER Returns          0.026563            0.012829            0.013375
# JSWENERGY Returns           0.040688            0.011812            0.019123
# OBEROIRLTY Returns          0.043204            0.018932            0.022865
# PERSISTENT Returns          0.016842            0.014600            0.008712
# PETRONET Returns            0.018871            0.005125            0.012747
# PIDILITIND Returns          0.019499            0.026602            0.011585
# PRESTIGE Returns            0.031938            0.012995            0.018352
# SUNPHARMA Returns           0.015864            0.006699            0.009564
# SUPREMEIND Returns          0.021599            0.007796            0.007442
# TORNTPOWER Returns          0.028765            0.008355            0.013459
# ULTRACEMCO Returns          0.025236            0.018406            0.011051
#
#                     BRITANNIA Returns  COALINDIA Returns  ADANIPORTS Returns  \
# ASHOKLEY Returns             0.010337           0.026117            0.037338
# ASIANPAINT Returns           0.012802           0.000440            0.021277
# BAJAJ-AUTO Returns           0.004946           0.010415            0.019047
# BRITANNIA Returns            0.039001           0.003351            0.011101
# COALINDIA Returns            0.003351           0.092857            0.036266
# ADANIPORTS Returns           0.011101           0.036266            0.157351
# APOLLOTYRE Returns           0.011548           0.029615            0.043259
# DIVISLAB Returns             0.002289           0.010559            0.015048
# LALPATHLAB Returns           0.010872           0.011960            0.017615
# GRASIM Returns               0.012844           0.021446            0.037241
# INDUSTOWER Returns           0.014409           0.024914            0.053938
# JSWENERGY Returns            0.008347           0.041209            0.052942
# OBEROIRLTY Returns           0.011296           0.029471            0.042652
# PERSISTENT Returns           0.008052           0.022782            0.027440
# PETRONET Returns             0.007450           0.028164            0.027648
# PIDILITIND Returns           0.012392           0.008598            0.022796
# PRESTIGE Returns             0.010165           0.022007            0.037837
# SUNPHARMA Returns            0.006967           0.014947            0.018650
# SUPREMEIND Returns           0.006695           0.015113            0.017762
# TORNTPOWER Returns           0.008589           0.035219            0.039690
# ULTRACEMCO Returns           0.011973           0.010840            0.027267
#
#                     APOLLOTYRE Returns  DIVISLAB Returns  LALPATHLAB Returns  \
# ASHOKLEY Returns              0.040421          0.011226            0.017466
# ASIANPAINT Returns            0.016228          0.014282            0.015933
# BAJAJ-AUTO Returns            0.020274          0.011626            0.005709
# BRITANNIA Returns             0.011548          0.002289            0.010872
# COALINDIA Returns             0.029615          0.010559            0.011960
# ADANIPORTS Returns            0.043259          0.015048            0.017615
# APOLLOTYRE Returns            0.100082          0.015708            0.015727
# DIVISLAB Returns              0.015708          0.073251            0.031086
# LALPATHLAB Returns            0.015727          0.031086            0.123547
# GRASIM Returns                0.030924          0.015882            0.016235
# INDUSTOWER Returns            0.032410          0.012570            0.013332
# JSWENERGY Returns             0.040209          0.015735            0.013435
# OBEROIRLTY Returns            0.038636          0.021912            0.022628
# PERSISTENT Returns            0.022341          0.017914            0.024327
# PETRONET Returns              0.022655          0.011153            0.009740
# PIDILITIND Returns            0.018317          0.014229            0.015226
# PRESTIGE Returns              0.031647          0.010234            0.013802
# SUNPHARMA Returns             0.017450          0.016123            0.012428
# SUPREMEIND Returns            0.019926          0.005982            0.009051
# TORNTPOWER Returns            0.030091          0.012138            0.017728
# ULTRACEMCO Returns            0.024319          0.013958            0.013529
#
#                     GRASIM Returns  ...  JSWENERGY Returns  \
# ASHOKLEY Returns          0.028729  ...           0.040688
# ASIANPAINT Returns        0.016840  ...           0.011812
# BAJAJ-AUTO Returns        0.013028  ...           0.019123
# BRITANNIA Returns         0.012844  ...           0.008347
# COALINDIA Returns         0.021446  ...           0.041209
# ADANIPORTS Returns        0.037241  ...           0.052942
# APOLLOTYRE Returns        0.030924  ...           0.040209
# DIVISLAB Returns          0.015882  ...           0.015735
# LALPATHLAB Returns        0.016235  ...           0.013435
# GRASIM Returns            0.057427  ...           0.027998
# INDUSTOWER Returns        0.031071  ...           0.032209
# JSWENERGY Returns         0.027998  ...           0.225000
# OBEROIRLTY Returns        0.035278  ...           0.046745
# PERSISTENT Returns        0.019811  ...           0.032761
# PETRONET Returns          0.012416  ...           0.025658
# PIDILITIND Returns        0.017792  ...           0.017951
# PRESTIGE Returns          0.024007  ...           0.032016
# SUNPHARMA Returns         0.012864  ...           0.014424
# SUPREMEIND Returns        0.016889  ...           0.020630
# TORNTPOWER Returns        0.021522  ...           0.039632
# ULTRACEMCO Returns        0.033371  ...           0.017917
#
#                     OBEROIRLTY Returns  PERSISTENT Returns  PETRONET Returns  \
# ASHOKLEY Returns              0.043204            0.016842          0.018871
# ASIANPAINT Returns            0.018932            0.014600          0.005125
# BAJAJ-AUTO Returns            0.022865            0.008712          0.012747
# BRITANNIA Returns             0.011296            0.008052          0.007450
# COALINDIA Returns             0.029471            0.022782          0.028164
# ADANIPORTS Returns            0.042652            0.027440          0.027648
# APOLLOTYRE Returns            0.038636            0.022341          0.022655
# DIVISLAB Returns              0.021912            0.017914          0.011153
# LALPATHLAB Returns            0.022628            0.024327          0.009740
# GRASIM Returns                0.035278            0.019811          0.012416
# INDUSTOWER Returns            0.038411            0.017611          0.023677
# JSWENERGY Returns             0.046745            0.032761          0.025658
# OBEROIRLTY Returns            0.129426            0.024110          0.018970
# PERSISTENT Returns            0.024110            0.116169          0.011832
# PETRONET Returns              0.018970            0.011832          0.060661
# PIDILITIND Returns            0.021192            0.012413          0.006009
# PRESTIGE Returns              0.064768            0.018207          0.014087
# SUNPHARMA Returns             0.013136            0.017375          0.009022
# SUPREMEIND Returns            0.014004            0.018355          0.001041
# TORNTPOWER Returns            0.034365            0.016917          0.020451
# ULTRACEMCO Returns            0.028983            0.017329          0.009412
#
#                     PIDILITIND Returns  PRESTIGE Returns  SUNPHARMA Returns  \
# ASHOKLEY Returns              0.019499          0.031938           0.015864
# ASIANPAINT Returns            0.026602          0.012995           0.006699
# BAJAJ-AUTO Returns            0.011585          0.018352           0.009564
# BRITANNIA Returns             0.012392          0.010165           0.006967
# COALINDIA Returns             0.008598          0.022007           0.014947
# ADANIPORTS Returns            0.022796          0.037837           0.018650
# APOLLOTYRE Returns            0.018317          0.031647           0.017450
# DIVISLAB Returns              0.014229          0.010234           0.016123
# LALPATHLAB Returns            0.015226          0.013802           0.012428
# GRASIM Returns                0.017792          0.024007           0.012864
# INDUSTOWER Returns            0.016750          0.028237           0.010318
# JSWENERGY Returns             0.017951          0.032016           0.014424
# OBEROIRLTY Returns            0.021192          0.064768           0.013136
# PERSISTENT Returns            0.012413          0.018207           0.017375
# PETRONET Returns              0.006009          0.014087           0.009022
# PIDILITIND Returns            0.048971          0.015403           0.006895
# PRESTIGE Returns              0.015403          0.162173           0.007778
# SUNPHARMA Returns             0.006895          0.007778           0.044827
# SUPREMEIND Returns            0.008150          0.008795           0.010362
# TORNTPOWER Returns            0.014115          0.030035           0.011748
# ULTRACEMCO Returns            0.015909          0.021678           0.010575
#
#                     SUPREMEIND Returns  TORNTPOWER Returns  ULTRACEMCO Returns
# ASHOKLEY Returns              0.021599            0.028765            0.025236
# ASIANPAINT Returns            0.007796            0.008355            0.018406
# BAJAJ-AUTO Returns            0.007442            0.013459            0.011051
# BRITANNIA Returns             0.006695            0.008589            0.011973
# COALINDIA Returns             0.015113            0.035219            0.010840
# ADANIPORTS Returns            0.017762            0.039690            0.027267
# APOLLOTYRE Returns            0.019926            0.030091            0.024319
# DIVISLAB Returns              0.005982            0.012138            0.013958
# LALPATHLAB Returns            0.009051            0.017728            0.013529
# GRASIM Returns                0.016889            0.021522            0.033371
# INDUSTOWER Returns            0.011960            0.031772            0.020358
# JSWENERGY Returns             0.020630            0.039632            0.017917
# OBEROIRLTY Returns            0.014004            0.034365            0.028983
# PERSISTENT Returns            0.018355            0.016917            0.017329
# PETRONET Returns              0.001041            0.020451            0.009412
# PIDILITIND Returns            0.008150            0.014115            0.015909
# PRESTIGE Returns              0.008795            0.030035            0.021678
# SUNPHARMA Returns             0.010362            0.011748            0.010575
# SUPREMEIND Returns            0.107033            0.008635            0.016604
# TORNTPOWER Returns            0.008635            0.118365            0.014992
# ULTRACEMCO Returns            0.016604            0.014992            0.052141
#
# [21 rows x 21 columns]

# %%
#single run
np.random.seed(101)
weights = np.array(np.random.random(21))
print('Random weights')
print(weights)
print('Rebalanced weights')
weights = weights/np.sum(weights)
print('Portfolio return')
port_ret = np.sum(returns.mean()*250*weights)
print(port_ret)
print('Expected volatility')
port_vol = np.sqrt(np.dot(weights.T, np.dot(returns.cov()*250,weights)))
print(port_vol)
print('Sharpe Ratio')
SR = (port_ret - 0.075)/port_vol
print(SR)
# Out:
# Random weights
# [0.51639863 0.57066759 0.02847423 0.17152166 0.68527698 0.83389686
#  0.30696622 0.89361308 0.72154386 0.18993895 0.55422759 0.35213195
#  0.1818924  0.78560176 0.96548322 0.23235366 0.08356143 0.60354842
#  0.72899276 0.27623883 0.68530633]
# Rebalanced weights
# Portfolio return
# 0.27192744777512984
# Expected volatility
# 0.15268665674714577
# Sharpe Ratio
# 1.2897489012497556

# %%
sim = 5000
all_weights = np.zeros((sim, len(symbol_list)))
ret_arr = np.zeros(sim)
vol_arr = np.zeros(sim)
sharpe_arr = np.zeros(sim)

for i in range(sim):
    weights = np.array(np.random.random(21))
    weights = weights/np.sum(weights)
    all_weights[i,:] = weights
    ret_arr[i] = np.sum(returns.mean()*250*weights)
    vol_arr[i] = np.sqrt(np.dot(weights.T,np.dot(returns.cov()*250,weights)))
    sharpe_arr[i] = (ret_arr[i] - 0.075)/vol_arr[i]

# %%
sharpe_arr.max()
# Out:
# 1.9188339785915278

# %%
sharpe_arr.argmax()
# Out:
# 4550

# %%
weights = all_weights[4550,:]

# %%
df = pd.DataFrame({
    'Symbol': symbol_list,
    'Weight': weights
})

# Sort the DataFrame by the weight values
df_sorted = df.sort_values(by='Weight', ascending=False)

# Display the sorted DataFrame
print(df_sorted)
# Out:
#         Symbol    Weight
# 2   BAJAJ-AUTO  0.102321
# 11   JSWENERGY  0.096699
# 19  TORNTPOWER  0.096591
# 17   SUNPHARMA  0.094302
# 13  PERSISTENT  0.076064
# 4    COALINDIA  0.072834
# 9       GRASIM  0.065826
# 18  SUPREMEIND  0.048113
# 14    PETRONET  0.047446
# 10  INDUSTOWER  0.044970
# 6   APOLLOTYRE  0.042571
# 16    PRESTIGE  0.036785
# 3    BRITANNIA  0.036712
# 20  ULTRACEMCO  0.030164
# 15  PIDILITIND  0.029503
# 5   ADANIPORTS  0.026249
# 0     ASHOKLEY  0.024256
# 8   LALPATHLAB  0.015427
# 12  OBEROIRLTY  0.010609
# 7     DIVISLAB  0.002286
# 1   ASIANPAINT  0.000272

# %%
df2 = df_sorted.head(n=10)
df2
# Out:
#         Symbol    Weight
# 2   BAJAJ-AUTO  0.102321
# 11   JSWENERGY  0.096699
# 19  TORNTPOWER  0.096591
# 17   SUNPHARMA  0.094302
# 13  PERSISTENT  0.076064
# 4    COALINDIA  0.072834
# 9       GRASIM  0.065826
# 18  SUPREMEIND  0.048113
# 14    PETRONET  0.047446
# 10  INDUSTOWER  0.044970

# %%
s = df2['Symbol'].tolist()
s
# Out:
# ['BAJAJ-AUTO',
#  'JSWENERGY',
#  'TORNTPOWER',
#  'SUNPHARMA',
#  'PERSISTENT',
#  'COALINDIA',
#  'GRASIM',
#  'SUPREMEIND',
#  'PETRONET',
#  'INDUSTOWER']
