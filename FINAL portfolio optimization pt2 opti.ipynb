# %%
import pandas as pd
import numpy as np
import yfinance as yf
import seaborn as sns
from yahoofinancials import YahooFinancials
from matplotlib import pyplot as plt

# %%
symbol_list = ['JSWENERGY',
 'ASHOKLEY',
 'LALPATHLAB',
 'PETRONET',
 'PERSISTENT',
 'SUNPHARMA',
 'PIDILITIND',
 'TORNTPOWER',
 'ULTRACEMCO',
 'SUPREMEIND']

# %%
start_date = "2021-04-01"
end_date = "2024-05-01"

# %%
data =[]
asset = []

# %%
for i in symbol_list:
    stock = pd.read_csv(f'{i}.csv', usecols=['Date','Close','Adj Close','Volume'])
    stock.set_index('Date', inplace=True)
    # Rename columns to include the stock symbol
    stock.columns = pd.MultiIndex.from_product([[i], stock.columns])
    #stock['Symbol'] = i
    data.append(stock)

# %%
type(data)
# Out:
# list

# %%
combined_df = pd.concat(data,axis=1)
# Reset index to ensure the 'Date' column is not part of the index
#combined_df.reset_index(inplace=True)

# %%
combined_df
# Out:
#              JSWENERGY                          ASHOKLEY              \
#                  Close   Adj Close    Volume       Close   Adj Close
# Date
# 2021-04-01   90.699997   88.316902  12835744  118.150002  109.928116
# 2021-04-05   86.550003   84.275948   5031925  113.349998  105.462135
# 2021-04-06   85.650002   83.399597   4786275  112.500000  104.671288
# 2021-04-07   89.400002   87.051071   7078339  116.750000  108.625549
# 2021-04-08   88.650002   86.320778   5101227  122.750000  114.208015
# ...                ...         ...       ...         ...         ...
# 2024-04-24  600.400024  598.428223   3340579  177.600006  177.600006
# 2024-04-25  604.700012  602.714111   1539624  177.699997  177.699997
# 2024-04-26  600.900024  598.926636   1929533  185.000000  185.000000
# 2024-04-29  603.299988  601.318665    917096  185.350006  185.350006
# 2024-04-30  629.549988  627.482483   5137464  192.649994  192.649994
#
#                        LALPATHLAB                          PETRONET  ...  \
#               Volume        Close    Adj Close   Volume       Close  ...
# Date                                                                 ...
# 2021-04-01  21938734  2730.600098  2672.518311   289605  227.750000  ...
# 2021-04-05  22361908  2898.300049  2836.651611   942719  227.399994  ...
# 2021-04-06  15611581  3061.000000  2995.890869   771927  228.149994  ...
# 2021-04-07  21921323  2987.350098  2923.807129   536999  230.899994  ...
# 2021-04-08  54015926  3133.449951  3066.799316  1029986  230.300003  ...
# ...              ...          ...          ...      ...         ...  ...
# 2024-04-24  13300471  2328.850098  2323.856689   541153  298.950012  ...
# 2024-04-25  11988994  2330.649902  2325.652588   116745  302.600006  ...
# 2024-04-26  48050897  2388.350098  2383.229004   266846  308.649994  ...
# 2024-04-29  15675179  2346.949951  2341.917725   425813  305.000000  ...
# 2024-04-30  55035190  2372.449951  2367.363037   197584  310.549988  ...
#
#            PIDILITIND   TORNTPOWER                         ULTRACEMCO  \
#                Volume        Close    Adj Close   Volume        Close
# Date
# 2021-04-01     462214   427.549988   397.117432   690448  6898.850098
# 2021-04-05     363509   416.100006   386.482422   742898  6795.799805
# 2021-04-06    1240064   418.100006   388.340088   627560  6736.649902
# 2021-04-07     620343   421.700012   391.683838   971550  6760.049805
# 2021-04-08     819770   422.500000   392.426910  1330315  6971.250000
# ...               ...          ...          ...      ...          ...
# 2024-04-24     283020  1515.099976  1511.307007   371208  9658.849609
# 2024-04-25     291095  1509.800049  1506.020386   306326  9683.750000
# 2024-04-26     250128  1489.800049  1486.070435   227797  9700.900391
# 2024-04-29     337877  1534.900024  1531.057495   694049  9964.450195
# 2024-04-30     477148  1501.099976  1497.342041  1052082  9971.849609
#
#                                   SUPREMEIND
#               Adj Close  Volume        Close    Adj Close   Volume
# Date
# 2021-04-01  6795.105957  531749  2020.800049  1935.501221    43191
# 2021-04-05  6693.605469  540954  2009.050049  1924.247314    22228
# 2021-04-06  6635.345215  508328  1980.199951  1896.614868    26345
# 2021-04-07  6658.393066  301479  1974.599976  1891.251221   107713
# 2021-04-08  6866.417480  635298  1981.650024  1898.003906    67005
# ...                 ...     ...          ...          ...      ...
# 2024-04-24  9658.849609  317929  4250.450195  4235.244141   107095
# 2024-04-25  9683.750000  398260  4303.500000  4288.104492    96264
# 2024-04-26  9700.900391  265782  4338.450195  4322.929688   584275
# 2024-04-29  9964.450195  808505  4955.149902  4937.422852  2767650
# 2024-04-30  9971.849609  777837  5062.100098  5043.990723   900529
#
# [760 rows x 30 columns]

# %%
combined_df.columns.names=['Company','Info']
combined_df
# Out:
# Company      JSWENERGY                          ASHOKLEY              \
# Info             Close   Adj Close    Volume       Close   Adj Close
# Date
# 2021-04-01   90.699997   88.316902  12835744  118.150002  109.928116
# 2021-04-05   86.550003   84.275948   5031925  113.349998  105.462135
# 2021-04-06   85.650002   83.399597   4786275  112.500000  104.671288
# 2021-04-07   89.400002   87.051071   7078339  116.750000  108.625549
# 2021-04-08   88.650002   86.320778   5101227  122.750000  114.208015
# ...                ...         ...       ...         ...         ...
# 2024-04-24  600.400024  598.428223   3340579  177.600006  177.600006
# 2024-04-25  604.700012  602.714111   1539624  177.699997  177.699997
# 2024-04-26  600.900024  598.926636   1929533  185.000000  185.000000
# 2024-04-29  603.299988  601.318665    917096  185.350006  185.350006
# 2024-04-30  629.549988  627.482483   5137464  192.649994  192.649994
#
# Company                LALPATHLAB                          PETRONET  ...  \
# Info          Volume        Close    Adj Close   Volume       Close  ...
# Date                                                                 ...
# 2021-04-01  21938734  2730.600098  2672.518311   289605  227.750000  ...
# 2021-04-05  22361908  2898.300049  2836.651611   942719  227.399994  ...
# 2021-04-06  15611581  3061.000000  2995.890869   771927  228.149994  ...
# 2021-04-07  21921323  2987.350098  2923.807129   536999  230.899994  ...
# 2021-04-08  54015926  3133.449951  3066.799316  1029986  230.300003  ...
# ...              ...          ...          ...      ...         ...  ...
# 2024-04-24  13300471  2328.850098  2323.856689   541153  298.950012  ...
# 2024-04-25  11988994  2330.649902  2325.652588   116745  302.600006  ...
# 2024-04-26  48050897  2388.350098  2383.229004   266846  308.649994  ...
# 2024-04-29  15675179  2346.949951  2341.917725   425813  305.000000  ...
# 2024-04-30  55035190  2372.449951  2367.363037   197584  310.549988  ...
#
# Company    PIDILITIND   TORNTPOWER                         ULTRACEMCO  \
# Info           Volume        Close    Adj Close   Volume        Close
# Date
# 2021-04-01     462214   427.549988   397.117432   690448  6898.850098
# 2021-04-05     363509   416.100006   386.482422   742898  6795.799805
# 2021-04-06    1240064   418.100006   388.340088   627560  6736.649902
# 2021-04-07     620343   421.700012   391.683838   971550  6760.049805
# 2021-04-08     819770   422.500000   392.426910  1330315  6971.250000
# ...               ...          ...          ...      ...          ...
# 2024-04-24     283020  1515.099976  1511.307007   371208  9658.849609
# 2024-04-25     291095  1509.800049  1506.020386   306326  9683.750000
# 2024-04-26     250128  1489.800049  1486.070435   227797  9700.900391
# 2024-04-29     337877  1534.900024  1531.057495   694049  9964.450195
# 2024-04-30     477148  1501.099976  1497.342041  1052082  9971.849609
#
# Company                           SUPREMEIND
# Info          Adj Close  Volume        Close    Adj Close   Volume
# Date
# 2021-04-01  6795.105957  531749  2020.800049  1935.501221    43191
# 2021-04-05  6693.605469  540954  2009.050049  1924.247314    22228
# 2021-04-06  6635.345215  508328  1980.199951  1896.614868    26345
# 2021-04-07  6658.393066  301479  1974.599976  1891.251221   107713
# 2021-04-08  6866.417480  635298  1981.650024  1898.003906    67005
# ...                 ...     ...          ...          ...      ...
# 2024-04-24  9658.849609  317929  4250.450195  4235.244141   107095
# 2024-04-25  9683.750000  398260  4303.500000  4288.104492    96264
# 2024-04-26  9700.900391  265782  4338.450195  4322.929688   584275
# 2024-04-29  9964.450195  808505  4955.149902  4937.422852  2767650
# 2024-04-30  9971.849609  777837  5062.100098  5043.990723   900529
#
# [760 rows x 30 columns]

# %%
returns = pd.DataFrame()
for stock in symbol_list:
    returns[stock+' Returns'] = combined_df[stock]['Adj Close'].pct_change()

# %%
returns.head()
#calculation of daily returns. 
#The daily percent changes is calculated using the 
#.pct_change(method) in a separate dataframe “returns”.
# Out:
#             JSWENERGY Returns  ASHOKLEY Returns  LALPATHLAB Returns  \
# Date
# 2021-04-01                NaN               NaN                 NaN
# 2021-04-05          -0.045755         -0.040626            0.061415
# 2021-04-06          -0.010399         -0.007499            0.056136
# 2021-04-07           0.043783          0.037778           -0.024061
# 2021-04-08          -0.008389          0.051392            0.048906
#
#             PETRONET Returns  PERSISTENT Returns  SUNPHARMA Returns  \
# Date
# 2021-04-01               NaN                 NaN                NaN
# 2021-04-05         -0.001537            0.002841          -0.003193
# 2021-04-06          0.003298           -0.010721           0.019136
# 2021-04-07          0.012053            0.012566           0.000967
# 2021-04-08         -0.002599            0.025813          -0.010949
#
#             PIDILITIND Returns  TORNTPOWER Returns  ULTRACEMCO Returns  \
# Date
# 2021-04-01                 NaN                 NaN                 NaN
# 2021-04-05           -0.012972           -0.026781           -0.014937
# 2021-04-06            0.041623            0.004807           -0.008704
# 2021-04-07            0.007469            0.008610            0.003473
# 2021-04-08            0.009108            0.001897            0.031242
#
#             SUPREMEIND Returns
# Date
# 2021-04-01                 NaN
# 2021-04-05           -0.005814
# 2021-04-06           -0.014360
# 2021-04-07           -0.002828
# 2021-04-08            0.003570

# %%
(returns.mean())*250
# Out:
# JSWENERGY Returns     0.757439
# ASHOKLEY Returns      0.229241
# LALPATHLAB Returns    0.021579
# PETRONET Returns      0.181517
# PERSISTENT Returns    0.473391
# SUNPHARMA Returns     0.328822
# PIDILITIND Returns    0.197882
# TORNTPOWER Returns    0.495929
# ULTRACEMCO Returns    0.152444
# SUPREMEIND Returns    0.368591
# dtype: float64

# %%
returns.cov()*250
# Out:
#                     JSWENERGY Returns  ASHOKLEY Returns  LALPATHLAB Returns  \
# JSWENERGY Returns            0.225000          0.040688            0.013435
# ASHOKLEY Returns             0.040688          0.088759            0.017466
# LALPATHLAB Returns           0.013435          0.017466            0.123547
# PETRONET Returns             0.025658          0.018871            0.009740
# PERSISTENT Returns           0.032761          0.016842            0.024327
# SUNPHARMA Returns            0.014424          0.015864            0.012428
# PIDILITIND Returns           0.017951          0.019499            0.015226
# TORNTPOWER Returns           0.039632          0.028765            0.017728
# ULTRACEMCO Returns           0.017917          0.025236            0.013529
# SUPREMEIND Returns           0.020630          0.021599            0.009051
#
#                     PETRONET Returns  PERSISTENT Returns  SUNPHARMA Returns  \
# JSWENERGY Returns           0.025658            0.032761           0.014424
# ASHOKLEY Returns            0.018871            0.016842           0.015864
# LALPATHLAB Returns          0.009740            0.024327           0.012428
# PETRONET Returns            0.060661            0.011832           0.009022
# PERSISTENT Returns          0.011832            0.116169           0.017375
# SUNPHARMA Returns           0.009022            0.017375           0.044827
# PIDILITIND Returns          0.006009            0.012413           0.006895
# TORNTPOWER Returns          0.020451            0.016917           0.011748
# ULTRACEMCO Returns          0.009412            0.017329           0.010575
# SUPREMEIND Returns          0.001041            0.018355           0.010362
#
#                     PIDILITIND Returns  TORNTPOWER Returns  \
# JSWENERGY Returns             0.017951            0.039632
# ASHOKLEY Returns              0.019499            0.028765
# LALPATHLAB Returns            0.015226            0.017728
# PETRONET Returns              0.006009            0.020451
# PERSISTENT Returns            0.012413            0.016917
# SUNPHARMA Returns             0.006895            0.011748
# PIDILITIND Returns            0.048971            0.014115
# TORNTPOWER Returns            0.014115            0.118365
# ULTRACEMCO Returns            0.015909            0.014992
# SUPREMEIND Returns            0.008150            0.008635
#
#                     ULTRACEMCO Returns  SUPREMEIND Returns
# JSWENERGY Returns             0.017917            0.020630
# ASHOKLEY Returns              0.025236            0.021599
# LALPATHLAB Returns            0.013529            0.009051
# PETRONET Returns              0.009412            0.001041
# PERSISTENT Returns            0.017329            0.018355
# SUNPHARMA Returns             0.010575            0.010362
# PIDILITIND Returns            0.015909            0.008150
# TORNTPOWER Returns            0.014992            0.008635
# ULTRACEMCO Returns            0.052141            0.016604
# SUPREMEIND Returns            0.016604            0.107033

# %% [markdown]
# #single run
# np.random.seed(101)
# weights = np.array(np.random.random(21))
# print('Random weights')
# print(weights)
# print('Rebalanced weights')
# weights = weights/np.sum(weights)
# print('Portfolio return')
# port_ret = np.sum(returns.mean()*250*weights)
# print(port_ret)
# print('Expected volatility')
# port_vol = np.sqrt(np.dot(weights.T, np.dot(returns.cov()*250,weights)))
# print(port_vol)
# print('Sharpe Ratio')
# SR = (port_ret - 0.075)/port_vol
# print(SR)

# %%
sim = 5000
all_weights = np.zeros((sim, len(symbol_list)))
ret_arr = np.zeros(sim)
vol_arr = np.zeros(sim)
sharpe_arr = np.zeros(sim)

for i in range(sim):
    weights = np.array(np.random.random(10))
    weights = weights/np.sum(weights)
    all_weights[i,:] = weights
    ret_arr[i] = np.sum(returns.mean()*250*weights)
    vol_arr[i] = np.sqrt(np.dot(weights.T,np.dot(returns.cov()*250,weights)))
    sharpe_arr[i] = (ret_arr[i] - 0.075)/vol_arr[i]

# %%
sharpe_arr.max()
# Out:
# 2.006414652812315

# %%
sharpe_arr.argmax()
# Out:
# 3776

# %%
weights = all_weights[3776,:]

# %%
df = pd.DataFrame({
    'Symbol': symbol_list,
    'Weight': weights
})

# Sort the DataFrame by the weight values
df_sorted = df.sort_values(by='Weight', ascending=False)

# Display the sorted DataFrame
print(df_sorted)
# Out:
#        Symbol    Weight
# 0   JSWENERGY  0.198001
# 5   SUNPHARMA  0.187309
# 4  PERSISTENT  0.165735
# 7  TORNTPOWER  0.144081
# 9  SUPREMEIND  0.140406
# 6  PIDILITIND  0.104469
# 8  ULTRACEMCO  0.036309
# 1    ASHOKLEY  0.015879
# 3    PETRONET  0.004618
# 2  LALPATHLAB  0.003193

# %%
type(df_prices2)
# Out:
# pandas.core.frame.DataFrame

# %%
stocks = df_sorted['Symbol'].tolist()
stocks
# Out:
# ['JSWENERGY',
#  'SUNPHARMA',
#  'PERSISTENT',
#  'TORNTPOWER',
#  'SUPREMEIND',
#  'PIDILITIND',
#  'ULTRACEMCO',
#  'ASHOKLEY',
#  'PETRONET',
#  'LALPATHLAB']

# %%
prices = []
start_date = '2020-04-01'
for symbol in stocks:
        # Fetch historical data from Yahoo Finance
        data = yf.download(symbol+".NS", start="2020-04-01", end='2020-04-02')
        price_april2020 = data.loc[start_date]['Adj Close']
        prices.append(price_april2020)
df_prices = pd.DataFrame({'Symbol': stocks, 'Price_April2020': prices})

# Display the prices
print(df_prices)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#        Symbol  Price_April2020
# 0   JSWENERGY        41.094852
# 1   SUNPHARMA       328.683624
# 2  PERSISTENT       262.679871
# 3  TORNTPOWER       256.646759
# 4  SUPREMEIND       801.269592
# 5  PIDILITIND      1281.602539
# 6  ULTRACEMCO      3083.698730
# 7    ASHOKLEY        38.239910
# 8    PETRONET       161.202744
# 9  LALPATHLAB      1351.888794

# %%
prices=[]

# %%
start_date = '2024-06-03'
for symbol in stocks:
        # Fetch historical data from Yahoo Finance
        data = yf.download(symbol+".NS", start="2024-06-03", end='2024-06-04')
        price_2024 = data.loc[start_date]['Adj Close']
        prices.append(price_2024)
df_prices2 = pd.DataFrame({'Symbol': stocks, 'Price_2024': prices})

# Display the prices
print(df_prices2)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#        Symbol    Price_2024
# 0   JSWENERGY    658.700012
# 1   SUNPHARMA   1448.456909
# 2  PERSISTENT   3418.380371
# 3  TORNTPOWER   1511.456665
# 4  SUPREMEIND   5547.382812
# 5  PIDILITIND   2984.600098
# 6  ULTRACEMCO  10470.049805
# 7    ASHOKLEY    236.500000
# 8    PETRONET    313.968658
# 9  LALPATHLAB   2668.416016

# %%
combined_df = pd.merge(df_prices, df_prices2, on='Symbol')

# %%
combined_df = pd.merge(df_sorted, combined_df, on='Symbol')

# %%
combined_df
# Out:
#        Symbol    Weight  Price_April2020    Price_2024
# 0   JSWENERGY  0.198001        41.094852    658.700012
# 1   SUNPHARMA  0.187309       328.683624   1448.456909
# 2  PERSISTENT  0.165735       262.679871   3418.380371
# 3  TORNTPOWER  0.144081       256.646759   1511.456665
# 4  SUPREMEIND  0.140406       801.269592   5547.382812
# 5  PIDILITIND  0.104469      1281.602539   2984.600098
# 6  ULTRACEMCO  0.036309      3083.698730  10470.049805
# 7    ASHOKLEY  0.015879        38.239910    236.500000
# 8    PETRONET  0.004618       161.202744    313.968658
# 9  LALPATHLAB  0.003193      1351.888794   2668.416016

# %%
portfolio_value = 10000000
combined_df['Investment'] = combined_df['Weight'] * portfolio_value
combined_df['Shares'] = (combined_df['Investment'] / combined_df['Price_April2020']).astype(int)

# Calculate the value of each stock on 1st June 2024
combined_df['Value_2024'] = combined_df['Shares'] * combined_df['Price_2024']

# Calculate total investment used and remaining cash
total_investment_used = (combined_df['Shares'] * combined_df['Price_April2020']).sum()
remaining_cash = portfolio_value - total_investment_used

# Calculate total portfolio value in June 2024 and profit/loss
total_value_2024 = combined_df['Value_2024'].sum()
profit_loss = total_value_2024 - total_investment_used

# %%
combined_df
# Out:
#        Symbol    Weight  Price_April2020    Price_2024    Investment  Shares  \
# 0   JSWENERGY  0.198001        41.094852    658.700012  1.980010e+06   48181
# 1   SUNPHARMA  0.187309       328.683624   1448.456909  1.873090e+06    5698
# 2  PERSISTENT  0.165735       262.679871   3418.380371  1.657353e+06    6309
# 3  TORNTPOWER  0.144081       256.646759   1511.456665  1.440806e+06    5613
# 4  SUPREMEIND  0.140406       801.269592   5547.382812  1.404061e+06    1752
# 5  PIDILITIND  0.104469      1281.602539   2984.600098  1.044686e+06     815
# 6  ULTRACEMCO  0.036309      3083.698730  10470.049805  3.630886e+05     117
# 7    ASHOKLEY  0.015879        38.239910    236.500000  1.587942e+05    4152
# 8    PETRONET  0.004618       161.202744    313.968658  4.618008e+04     286
# 9  LALPATHLAB  0.003193      1351.888794   2668.416016  3.193141e+04      23
#
#      Value_2024
# 0  3.173683e+07
# 1  8.253307e+06
# 2  2.156656e+07
# 3  8.483806e+06
# 4  9.719015e+06
# 5  2.432449e+06
# 6  1.224996e+06
# 7  9.819480e+05
# 8  8.979504e+04
# 9  6.137357e+04

# %%
# Display the final DataFrame and summary
print(combined_df)
print("\nSummary:")
print(f"Total Investment Used: Rs.{total_investment_used:.2f}")
print(f"Remaining Cash: Rs.{remaining_cash:.2f}")
print(f"Total Portfolio Value in June 2024: Rs.{total_value_2024:.2f}")
print(f"Total Profit: Rs.{profit_loss:.2f}")
print(f"Total Profit %: {profit_loss/total_investment_used*100:.2f}")
# Out:
#        Symbol    Weight  Price_April2020    Price_2024    Investment  Shares  \
# 0   JSWENERGY  0.198001        41.094852    658.700012  1.980010e+06   48181
# 1   SUNPHARMA  0.187309       328.683624   1448.456909  1.873090e+06    5698
# 2  PERSISTENT  0.165735       262.679871   3418.380371  1.657353e+06    6309
# 3  TORNTPOWER  0.144081       256.646759   1511.456665  1.440806e+06    5613
# 4  SUPREMEIND  0.140406       801.269592   5547.382812  1.404061e+06    1752
# 5  PIDILITIND  0.104469      1281.602539   2984.600098  1.044686e+06     815
# 6  ULTRACEMCO  0.036309      3083.698730  10470.049805  3.630886e+05     117
# 7    ASHOKLEY  0.015879        38.239910    236.500000  1.587942e+05    4152
# 8    PETRONET  0.004618       161.202744    313.968658  4.618008e+04     286
# 9  LALPATHLAB  0.003193      1351.888794   2668.416016  3.193141e+04      23
#
#      Value_2024
# 0  3.173683e+07
# 1  8.253307e+06
# 2  2.156656e+07
# 3  8.483806e+06
# 4  9.719015e+06
# 5  2.432449e+06
# 6  1.224996e+06
# 7  9.819480e+05
# 8  8.979504e+04
# 9  6.137357e+04
#
# Summary:
# Total Investment Used: Rs.9995728.62
# Remaining Cash: Rs.4271.38
# Total Portfolio Value in June 2024: Rs.84550076.98
# Total Profit: Rs.74554348.36
# Total Profit %: 745.86
